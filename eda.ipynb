# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from io import StringIO
data="""

EmployeeID,Name,Age,Gender,Salary,Department,JoiningDate,Email,Experience
101,John Smith,28,Male,45000,IT,2022-05-12,john.smith@gmail.com,3
102,Alice Johnson,32,Female,52000,HR,2021-08-15,alice@gmail.com,5
103,Bob Williams,,Male,48000,IT,2022/03/20,bob.williams@gmail.com,4
104,Emma Brown,27,Female,,Finance,2023-01-10,emma.brown@gmail.com,2
105,Michael Davis,150,Male,60000,IT,2020-11-05,michael@gmail.com,8
106,Sophia Miller,29,Female,55000,HR,15-06-2021,sophia@gmail,5
107,David Wilson,31,Male,-10000,Finance,2022-07-18,david@gmail.com,6
108,Olivia Moore,26,Female,47000,IT,2023-04-12,olivia@gmail.com,2
109,James Taylor,29,Male,47000,it,2023-04-12,james@gmail.com,2
110,John Smith,28,Male,45000,IT,2022-05-12,john.smith@gmail.com,3
111,,35,Female,58000,HR,2021-02-01,missingname@gmail.com,7
112,Daniel Anderson,abc,Male,50000,Finance,2022-09-09,daniel@gmail.com,4
113,Isabella Thomas,30,Female,9999999,Finance,2022-06-01,isabella@gmail.com,5
114,Ethan Jackson,24,Male,42000,IT,2024-01-01,ethan@gmail.com,1
115,Mia White,29,Female,51000,Marketing,2022-12-15,mia@gmail.com,4
116,Noah Harris,31,Male,53000,Marketing,2022-12-15,noah@gmail.com,4
117,Ava Martin,29,Female,51000,marketing,2022-12-15,ava@gmail.com,4
118,Liam Thompson,30,Male,52000,HR,,liam@gmail.com,5
119,Charlotte Garcia,28,Female,49000,Finance,2022-10-10,charlotte@gmail.com,3
120,William Martinez,29,Male,50000,IT,2022-08-08,william@gmail.com,3"""
df=pd.read_csv(StringIO(data))
df_co=df.copy()

# %%
df_co['Age']=pd.to_numeric(df_co['Age'],errors='coerce')

# %%
df_co=df_co.dropna(subset=['Name'])

# %%
df_co
# Out:
#     EmployeeID              Name    Age  Gender     Salary Department  \
# 0          101        John Smith   28.0    Male    45000.0         IT
# 1          102     Alice Johnson   32.0  Female    52000.0         HR
# 2          103      Bob Williams    NaN    Male    48000.0         IT
# 3          104        Emma Brown   27.0  Female        NaN    Finance
# 4          105     Michael Davis  150.0    Male    60000.0         IT
# 5          106     Sophia Miller   29.0  Female    55000.0         HR
# 6          107      David Wilson   31.0    Male   -10000.0    Finance
# 7          108      Olivia Moore   26.0  Female    47000.0         IT
# 8          109      James Taylor   29.0    Male    47000.0         it
# 9          110        John Smith   28.0    Male    45000.0         IT
# 11         112   Daniel Anderson    NaN    Male    50000.0    Finance
# 12         113   Isabella Thomas   30.0  Female  9999999.0    Finance
# ...

# %%
neg_row=df_co[df_co['Salary']<0]
neg_row
df_co.drop(neg_row.index,inplace=True)

# %%
df_co
# Out:
#     EmployeeID              Name    Age  Gender     Salary Department  \
# 0          101        John Smith   28.0    Male    45000.0         IT
# 1          102     Alice Johnson   32.0  Female    52000.0         HR
# 2          103      Bob Williams    NaN    Male    48000.0         IT
# 3          104        Emma Brown   27.0  Female        NaN    Finance
# 4          105     Michael Davis  150.0    Male    60000.0         IT
# 5          106     Sophia Miller   29.0  Female    55000.0         HR
# 7          108      Olivia Moore   26.0  Female    47000.0         IT
# 8          109      James Taylor   29.0    Male    47000.0         it
# 9          110        John Smith   28.0    Male    45000.0         IT
# 11         112   Daniel Anderson    NaN    Male    50000.0    Finance
# 12         113   Isabella Thomas   30.0  Female  9999999.0    Finance
# 13         114     Ethan Jackson   24.0    Male    42000.0         IT
# ...

# %%
df_co['Salary'].median()
# Out:
# np.float64(50000.0)

# %%
df_co.fillna(df_co['Salary'].median())
# Out:
#     EmployeeID              Name      Age  Gender     Salary Department  \
# 0          101        John Smith     28.0    Male    45000.0         IT
# 1          102     Alice Johnson     32.0  Female    52000.0         HR
# 2          103      Bob Williams  50000.0    Male    48000.0         IT
# 3          104        Emma Brown     27.0  Female    50000.0    Finance
# 4          105     Michael Davis    150.0    Male    60000.0         IT
# 5          106     Sophia Miller     29.0  Female    55000.0         HR
# 7          108      Olivia Moore     26.0  Female    47000.0         IT
# 8          109      James Taylor     29.0    Male    47000.0         it
# 9          110        John Smith     28.0    Male    45000.0         IT
# 11         112   Daniel Anderson  50000.0    Male    50000.0    Finance
# 12         113   Isabella Thomas     30.0  Female  9999999.0    Finance
# 13         114     Ethan Jackson     24.0    Male    42000.0         IT
# ...

# %%
df_co
# Out:
#     EmployeeID              Name    Age  Gender     Salary Department  \
# 0          101        John Smith   28.0    Male    45000.0         IT
# 1          102     Alice Johnson   32.0  Female    52000.0         HR
# 2          103      Bob Williams    NaN    Male    48000.0         IT
# 3          104        Emma Brown   27.0  Female        NaN    Finance
# 4          105     Michael Davis  150.0    Male    60000.0         IT
# 5          106     Sophia Miller   29.0  Female    55000.0         HR
# 7          108      Olivia Moore   26.0  Female    47000.0         IT
# 8          109      James Taylor   29.0    Male    47000.0         it
# 9          110        John Smith   28.0    Male    45000.0         IT
# 11         112   Daniel Anderson    NaN    Male    50000.0    Finance
# 12         113   Isabella Thomas   30.0  Female  9999999.0    Finance
# 13         114     Ethan Jackson   24.0    Male    42000.0         IT
# ...

# %%
df_co=df_co.drop_duplicates(subset=['Name'])

# %%
df_co
# Out:
#     EmployeeID              Name    Age  Gender     Salary Department  \
# 0          101        John Smith   28.0    Male    45000.0         IT
# 1          102     Alice Johnson   32.0  Female    52000.0         HR
# 2          103      Bob Williams    NaN    Male    48000.0         IT
# 3          104        Emma Brown   27.0  Female        NaN    Finance
# 4          105     Michael Davis  150.0    Male    60000.0         IT
# 5          106     Sophia Miller   29.0  Female    55000.0         HR
# 7          108      Olivia Moore   26.0  Female    47000.0         IT
# 8          109      James Taylor   29.0    Male    47000.0         it
# 11         112   Daniel Anderson    NaN    Male    50000.0    Finance
# 12         113   Isabella Thomas   30.0  Female  9999999.0    Finance
# 13         114     Ethan Jackson   24.0    Male    42000.0         IT
# 14         115         Mia White   29.0  Female    51000.0  Marketing
# ...

# %%
df_co.drop_duplicates(subset=['Name'])
# Out:
#     EmployeeID              Name    Age  Gender     Salary Department  \
# 0          101        John Smith   28.0    Male    45000.0         IT
# 1          102     Alice Johnson   32.0  Female    52000.0         HR
# 2          103      Bob Williams    NaN    Male    48000.0         IT
# 3          104        Emma Brown   27.0  Female        NaN    Finance
# 4          105     Michael Davis  150.0    Male    60000.0         IT
# 5          106     Sophia Miller   29.0  Female    55000.0         HR
# 7          108      Olivia Moore   26.0  Female    47000.0         IT
# 8          109      James Taylor   29.0    Male    47000.0         it
# 11         112   Daniel Anderson    NaN    Male    50000.0    Finance
# 12         113   Isabella Thomas   30.0  Female  9999999.0    Finance
# 13         114     Ethan Jackson   24.0    Male    42000.0         IT
# 14         115         Mia White   29.0  Female    51000.0  Marketing
# ...

# %%
df_co[df_co['Age']>100]
# Out:
#    EmployeeID           Name    Age Gender   Salary Department JoiningDate  \
# 4         105  Michael Davis  150.0   Male  60000.0         IT  2020-11-05
#
#                Email  Experience
# 4  michael@gmail.com           8

# %%
#to replace we use loc
df_co.loc[df_co['Age']>100,'Age']=pd.NA

# %%
df_co
# Out:
#     EmployeeID              Name   Age  Gender     Salary Department  \
# 0          101        John Smith  28.0    Male    45000.0         IT
# 1          102     Alice Johnson  32.0  Female    52000.0         HR
# 2          103      Bob Williams   NaN    Male    48000.0         IT
# 3          104        Emma Brown  27.0  Female        NaN    Finance
# 4          105     Michael Davis   NaN    Male    60000.0         IT
# 5          106     Sophia Miller  29.0  Female    55000.0         HR
# 7          108      Olivia Moore  26.0  Female    47000.0         IT
# 8          109      James Taylor  29.0    Male    47000.0         it
# 11         112   Daniel Anderson   NaN    Male    50000.0    Finance
# 12         113   Isabella Thomas  30.0  Female  9999999.0    Finance
# 13         114     Ethan Jackson  24.0    Male    42000.0         IT
# 14         115         Mia White  29.0  Female    51000.0  Marketing
# 15         116       Noah Harris  31.0    Male    53000.0  Marketing
# ...

# %%
df_co['Salary'].median()
# Out:
# np.float64(50500.0)

# %%
df_co['Salary']=df_co['Salary'].fillna(df_co['Salary'].median(),inplace=True)
# Out:
# C:\Users\CVR\AppData\Local\Temp\ipykernel_13492\207116777.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_co['Salary']=df_co['Salary'].fillna(df_co['Salary'].median(),inplace=True)

# %%
df_co
# Out:
#     EmployeeID              Name   Age  Gender     Salary Department  \
# 0          101        John Smith  28.0    Male    45000.0         IT
# 1          102     Alice Johnson  32.0  Female    52000.0         HR
# 2          103      Bob Williams   NaN    Male    48000.0         IT
# 3          104        Emma Brown  27.0  Female    50500.0    Finance
# 4          105     Michael Davis   NaN    Male    60000.0         IT
# 5          106     Sophia Miller  29.0  Female    55000.0         HR
# 7          108      Olivia Moore  26.0  Female    47000.0         IT
# 8          109      James Taylor  29.0    Male    47000.0         it
# 11         112   Daniel Anderson   NaN    Male    50000.0    Finance
# 12         113   Isabella Thomas  30.0  Female  9999999.0    Finance
# 13         114     Ethan Jackson  24.0    Male    42000.0         IT
# 14         115         Mia White  29.0  Female    51000.0  Marketing
# 15         116       Noah Harris  31.0    Male    53000.0  Marketing
# ...

# %%
#we hava a outlier in the salary col which 9999999
#inorder to deal with that we have to perfor IQR
#to find the abnormal salalries sort it 
df_co['Salary'].sort_values()
# Out:
# 13      42000.0
# 0       45000.0
# 7       47000.0
# 8       47000.0
# 2       48000.0
# 18      49000.0
# 11      50000.0
# 19      50000.0
# 3       50500.0
# 16      51000.0
# 14      51000.0
# 1       52000.0
# 17      52000.0
# 15      53000.0
# 5       55000.0
# 4       60000.0
# 12    9999999.0
# Name: Salary, dtype: float64

# %%
#IQR
q1=df_co['Salary'].quantile(0.25)
q3=df_co['Salary'].quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q1+1.5*iqr
print(f"{q1},{iqr},{q3}")
ou=df_co[(df_co['Salary']<lower) | (df_co['Salary']>upper)]
ou
# Out:
# 48000.0,4000.0,52000.0
#     EmployeeID             Name   Age  Gender     Salary Department  \
# 4          105    Michael Davis   NaN    Male    60000.0         IT
# 5          106    Sophia Miller  29.0  Female    55000.0         HR
# 12         113  Isabella Thomas  30.0  Female  9999999.0    Finance
#
#    JoiningDate               Email  Experience
# 4   2020-11-05   michael@gmail.com           8
# 5   15-06-2021        sophia@gmail           5
# 12  2022-06-01  isabella@gmail.com           5

# %%
df_co=df_co[(df_co['Salary']>=lower) & (df_co['Salary']<=upper)]
df_co
# Out:
#     EmployeeID              Name   Age  Gender   Salary Department  \
# 0          101        John Smith  28.0    Male  45000.0         IT
# 1          102     Alice Johnson  32.0  Female  52000.0         HR
# 2          103      Bob Williams   NaN    Male  48000.0         IT
# 3          104        Emma Brown  27.0  Female  50500.0    Finance
# 7          108      Olivia Moore  26.0  Female  47000.0         IT
# 8          109      James Taylor  29.0    Male  47000.0         it
# 11         112   Daniel Anderson   NaN    Male  50000.0    Finance
# 13         114     Ethan Jackson  24.0    Male  42000.0         IT
# 14         115         Mia White  29.0  Female  51000.0  Marketing
# 15         116       Noah Harris  31.0    Male  53000.0  Marketing
# 16         117        Ava Martin  29.0  Female  51000.0  marketing
# 17         118     Liam Thompson  30.0    Male  52000.0         HR
# 18         119  Charlotte Garcia  28.0  Female  49000.0    Finance
# ...

# %%
df['Department'].unique()
# Out:
# <StringArray>
# ['IT', 'HR', 'Finance', 'it', 'Marketing', 'marketing']
# Length: 6, dtype: str

# %%
df_co['Department'] = (
    df_co['Department']
    .str.upper()
)
